# %% [markdown]
# <a href="https://colab.research.google.com/github/ruan1700/Skyline-Math-200/blob/main/Lab_1_1_Data_Types_(First_Lastname).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome to your first Data of the year.  In this lab we with learn to
#
#
#
#
# 1.   Read in Data using **Pandas**
# 2.   View information about the data
# *   View the Numbers of rows and columns
# *   View the data type of each values

# %%
#First Import the Pandas library
import pandas as pd

# %%
link = 'https://raw.githubusercontent.com/kmath22/kmath22/main/Delivery%20App_csv.csv'

eats_df = pd.read_csv(link)

# %%
#View data
eats_df
# Out:
#           App  grandtotal  delivery_fee  subtotal    tip  Delivery_last_week  \
# 0    Doordash       20.00          3.00     15.00   2.00                   1
# 1    Doordash       27.27          2.99     17.92   3.00                   1
# 2     Grubhub       60.63          0.00     48.59   7.91                   1
# 3    Doordash       25.42         30.42      0.00   3.00                   0
# 4    Doordash       19.03          3.99      7.28   3.00                   4
# ..        ...         ...           ...       ...    ...                 ...
# 81   Doordash       27.81          0.00     19.80   4.00                   0
# 82  Uber Eats       29.30          4.99     15.80   4.88                   0
# 83  Uber Eats       16.93          0.00      1.55   0.00                   0
# 84  Uber Eats      117.00          0.49     87.75  15.10                   0
# 85    Grubhub       34.12          8.56     25.56   5.00                   1
#
# ...

# %%
#View only the first 5 rows of data

# %%
#View only the last 5 rows of data

# %%
#check the data and data types (Quantitiave and Categorical variables)

# %%
#Check the shape of the data

# %%
#View a variable or column from the data set 2 ways
#Method 1

# %%
#View a variable or column from the data set 2 ways
#Method 2

# %%
#Use dtype to view the variable type of the column
eats_df['App']
# Out:
# 0      Doordash
# 1      Doordash
# 2       Grubhub
# 3      Doordash
# 4      Doordash
#         ...
# 81     Doordash
# 82    Uber Eats
# 83    Uber Eats
# 84    Uber Eats
# 85      Grubhub
# Name: App, Length: 86, dtype: object

# %% [markdown]
# Part 2: You will now Python to answer questions on your own using the Data Scientist Salary Dataset

# %%
import pandas as pd

# %% [markdown]
# ## Upload the diamond dataset in Github
#
# ## *   Goto Github and click on the diamond dataset
# ## *   Click on the raw
#
# # * Copy the URL link
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#Upload the diamond dataset in Github
# Goto raw
link2 =''

diamond_df = pd.read_csv(link2)

# %%
#view diamond_df

# %%
#View only the first 8 rows of data

# %%
#View only the last 6 rows of data

# %%
#check the data and data types (Quantitiave and Categorical variables)

# %%
#Check the shape of the data

# %%
#View a variable or column from the data set 2 ways
#Method 1

# %%
#View a variable or column from the data set 2 ways
#Method 2

# %%
#Use dtype to view the variable type of the column
